# %%
from utils import visualize

# %%
filename = "labeled_7_ADB_0"

# %%
visualize.scatterplot(filename)

# %%
visualize.fine_grained_performance(filename)

# %%
visualize.detailed_error_analysis(filename)
